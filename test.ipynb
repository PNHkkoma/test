# %%
import compositional as coda
import pandas as pd

# Load abundances (Gomez and Espinoza et al. 2017)
X = pd.read_csv("https://github.com/jolespin/projects/raw/main/supragingival_plaque_microbiome/16S_amplicons/Data/X.tsv.gz", 
                sep="\t",
                index_col=0,
                compression="gzip",
)

# Load metadata
Y = pd.read_csv("https://github.com/jolespin/projects/raw/main/supragingival_plaque_microbiome/16S_amplicons/Data/Y.tsv.gz", 
                sep="\t",
                index_col=0,
                compression="gzip",
).loc[X.index]


print(X)
# X.shape: (n=473 samples, m=481 OTUs)

# Classes
classes = pd.Series(((Y["Caries_enamel"] == "YES").astype(int) + (Y["Caries_dentine"] == "YES").astype(int)).map(lambda x: {True:"Caries", False:"Caries-free"}[x > 0]), name="Diagnosis")

class_colors = {"Caries-free":"black", "Caries":"red"}
# Out:
#                   Otu000514  Otu000001  Otu000038  Otu000003  Otu000326  \
# S-1409-45.B_RD1          87       3802        685       2175          0
# 1104.2_RD1               23        463          0       4420          5
# S-1409-42.B_RD1         135       2023        539        540          0
# 1073.1_RD1              140       2012         30       4759         29
# A-1504-100.B_RD1        137        798         66       4769         24
# ...                     ...        ...        ...        ...        ...
# 1046.1_RD1               63        946         16        987          7
# M-1507-132.A_RD1         50        554         28       1182          1
# 2005.1_RD1              314      13540        172       4449         11
# S-1410-40.B_RD1          10       3061        342        608          0
# C-1504-92.B_RD1         192       1331         72       1058         14
#
#                   Otu000002  Otu000387  Otu000043  Otu000051  Otu000011  ...  \
# S-1409-45.B_RD1         684        463         88          1        411  ...
# 1104.2_RD1             2011        134         34         12        705  ...
# S-1409-42.B_RD1         395        399        218         24        839  ...
# 1073.1_RD1             6986        762         13          0        215  ...
# A-1504-100.B_RD1       2097        125         81          0        315  ...
# ...                     ...        ...        ...        ...        ...  ...
# 1046.1_RD1             2155        840          5          0        131  ...
# M-1507-132.A_RD1        789         46          1          0         75  ...
# 2005.1_RD1             2597       1454         25         14        163  ...
# S-1410-40.B_RD1        1246        827         32          0        202  ...
# C-1504-92.B_RD1        6617        265         39          0       1772  ...
#
#                   Otu000510  Otu000509  Otu000231  Otu000307  Otu000336  \
# S-1409-45.B_RD1           0          0          0          0          0
# 1104.2_RD1                0          0          0          0          0
# S-1409-42.B_RD1           0          0          0          0          0
# 1073.1_RD1                0          0          0          0          0
# A-1504-100.B_RD1          0          0          0          0          0
# ...                     ...        ...        ...        ...        ...
# 1046.1_RD1                0          0          0          0          0
# M-1507-132.A_RD1          0          0          0          0          0
# 2005.1_RD1                0          0          0          0          0
# S-1410-40.B_RD1           0          0          0          0          0
# C-1504-92.B_RD1           0          0          0          0          0
#
#                   Otu000416  Otu000555  Otu000556  Otu000542  Otu000526
# S-1409-45.B_RD1           0          0          0          0          0
# 1104.2_RD1                0          0          0          0          0
# S-1409-42.B_RD1           0          0          0          0          0
# 1073.1_RD1                0          0          0          0          0
# A-1504-100.B_RD1          0          0          0          0          0
# ...                     ...        ...        ...        ...        ...
# 1046.1_RD1                0          0          0          0          0
# M-1507-132.A_RD1          0          0          0          0          0
# 2005.1_RD1                0          0          0          0          0
# S-1410-40.B_RD1           0          0          0          0          0
# C-1504-92.B_RD1           0          0          0          0          0
#
# [473 rows x 481 columns]

# %%
X_filtered = coda.filter_data_highpass(
    X=X, 
    minimum_total_counts=10000,
    minimum_prevalence=0.5,
    minimum_components=50,
)

X.shape, X_filtered.shape
# ((473, 481), (401, 93))
# Out:
# ((473, 481), (401, 93))

# %%
# Sparsity
s = coda.sparsity(X)
print("Ratio of zeros in dataset: {:.3f}".format(s))
# Ratio of zeros in dataset: 0.776

# Total number of components per composition (i.e., richness)
coda.number_of_components(X).head()
# S-1409-45.B_RD1     111
# 1104.2_RD1           84
# S-1409-42.B_RD1     142
# 1073.1_RD1          101
# A-1504-100.B_RD1     95

# Prevalence of components across compositions
coda.prevalence_of_components(X).head()
# Otu000514    470
# Otu000001    473
# Otu000038    472
# Otu000003    473
# Otu000326    432
# Out:
# Ratio of zeros in dataset: 0.776
# Otu000514    470
# Otu000001    473
# Otu000038    472
# Otu000003    473
# Otu000326    432
# dtype: int64

# %%
# Pairwise Aitchison distance (redundant form)
aitchison_distances = coda.pairwise_aitchison_distance(X + 1, redundant_form=True)
# print(aitchison_distances.iloc[:4,:4])
#                  S-1409-45.B_RD1  1104.2_RD1  S-1409-42.B_RD1  1073.1_RD1
# S-1409-45.B_RD1         0.000000   25.384218        21.573635   23.455055
# 1104.2_RD1             25.384218    0.000000        27.811292   21.942080
# S-1409-42.B_RD1        21.573635   27.811292         0.000000   26.734435
# 1073.1_RD1             23.455055   21.942080        26.734435    0.000000

# Pairwise Aitchison distance (non-redundant form)
aitchison_distances = coda.pairwise_aitchison_distance(X + 1, redundant_form=False)
# print(aitchison_distances)
# aitchison_distance
# (S-1409-45.B_RD1, 1104.2_RD1)          25.384218
# (S-1409-45.B_RD1, S-1409-42.B_RD1)     21.573635
# (S-1409-45.B_RD1, 1073.1_RD1)          23.455055
# (S-1409-45.B_RD1, A-1504-100.B_RD1)    21.330042
# (S-1409-45.B_RD1, 2053.2_RD1)          22.531754
#                                          ...    
# (S-1410-40.B_RD1, M-1507-132.A_RD1)    23.247654
# (M-1507-132.A_RD1, C-1504-92.B_RD1)    20.422768
# (S-1410-40.B_RD1, 2005.1_RD1)          22.294198
# (2005.1_RD1, C-1504-92.B_RD1)          21.323598
# (S-1410-40.B_RD1, C-1504-92.B_RD1)     21.073093
# Length: 111628, dtype: float64

# %%
# Pairwise variance log-ratio
vlr = coda.pairwise_vlr(X + 1)
# print(vlr.iloc[:4,:4])
#            Otu000514  Otu000001  Otu000038  Otu000003
# Otu000514   0.000000   0.764679   1.844322   1.869921
# Otu000001   0.764679   0.000000   1.299599   1.230553
# Otu000038   1.844322   1.299599   0.000000   2.207001
# Otu000003   1.869921   1.230553   2.207001   0.000000

# Pairwise rho from Erb et al. 2016
rhos = coda.pairwise_rho(X + 1)
# print(rhos.iloc[:4,:4])
#            Otu000514  Otu000001  Otu000038  Otu000003
# Otu000514   1.000000   0.708325   0.304007   0.298552
# Otu000001   0.708325   1.000000   0.355895   0.394880
# Otu000038   0.304007   0.355895   1.000000  -0.070423
# Otu000003   0.298552   0.394880  -0.070423   1.000000

# Pairwise phi from Erb et al. 2016
phis = coda.pairwise_phi(X + 1)
# print(phis.iloc[:4,:4])
#            Otu000514  Otu000001  Otu000038  Otu000003
# Otu000514   0.000000   0.470005   1.133602   1.149336
# Otu000001   0.470005   0.000000   1.306492   1.237079
# Otu000038   1.133602   1.306492   0.000000   2.157470
# Otu000003   1.149336   1.237079   2.157470   0.000000

# %%
# Pairwise partial correlation with basis shrinkage from Erb et al. 2020 and Jin et al. 2022
pcorr = coda.pairwise_partial_correlation_with_basis_shrinkage(X + 1)
# print(pcorr.iloc[:4,:4])
#            Otu000514  Otu000001  Otu000038  Otu000003
# Otu000514   1.000000   0.256310  -0.022194  -0.005131
# Otu000001   0.256310   1.000000   0.105960   0.222187
# Otu000038  -0.022194   0.105960   1.000000  -0.042785
# Otu000003  -0.005131   0.222187  -0.042785   1.000000

# %%
# Isometric log-ratio
X_ilr_without_tree = coda.transform_ilr(X + 1)
print(X_ilr_without_tree.iloc[:4,:4])
#                         0         1         2         3
# S-1409-45.B_RD1 -2.663112 -0.139161 -1.098112  6.023297
# 1104.2_RD1      -2.094331  3.804032 -4.579665  2.357939
# S-1409-42.B_RD1 -1.909313 -0.023536 -0.018245  5.614873
# 1073.1_RD1      -1.879929  2.322184 -2.717553  2.426881
# Out:
#                         0         1         2         3
# S-1409-45.B_RD1 -2.663112 -0.139161 -1.098112  6.023297
# 1104.2_RD1      -2.094331  3.804032 -4.579665  2.357939
# S-1409-42.B_RD1 -1.909313 -0.023536 -0.018245  5.614873
# 1073.1_RD1      -1.879929  2.322184 -2.717553  2.426881

# %%
import requests
from io import StringIO
from skbio import TreeNode

# Get newick tree
url = "https://github.com/jolespin/projects/raw/main/supragingival_plaque_microbiome/16S_amplicons/Data/otus.alignment.fasttree.nw"
newick = requests.get(url).text
tree = TreeNode.read(StringIO(newick), convert_underscores=False)
tree.bifurcate()
print(tree)
# Name internal nodes
intermediate_node_index = 1
for node in tree.traverse():
    if not node.is_tip():
        node.name = "y{}".format(intermediate_node_index)
        intermediate_node_index += 1

# Isometric log-ratio transform
X_ilr_with_tree = coda.transform_ilr(X + 1, tree)
# print(X_ilr_with_tree.iloc[:4,:4])
#                        y1        y2          y480            y3
# S-1409-45.B_RD1 -1.039407  1.655538 -2.464164e-17  6.189481e-16
# 1104.2_RD1      -0.673964  1.073470  4.192522e-18  3.923163e-16
# S-1409-42.B_RD1 -1.326432  2.112703  3.851113e-17  8.306736e-16
# 1073.1_RD1      -0.979605  1.560287  5.023995e-18  5.907717e-16
# Out:
# ((((Otu000275:0.007613678,Otu000367:0.017826284)0.734:0.005119825,(Otu000718:0.012788311,(Otu000228:5e-09,Otu000427:0.02397072)0.914:0.010333985)0.875:0.01072808)0.895:0.011191495,((Otu000386:0.020963363,Otu000453:0.015133357)0.890:0.012102115,(Otu000795:0.02329493,((Otu000257:0.052011182,(((Otu000677:0.016787526,(((Otu000434:0.034341633,((Otu000424:0.012593343,(Otu000041:0.020727734,Otu000511:0.002470353)0.811:0.005253225)0.996:0.046119596,(((((Otu000143:5e-09,(Otu000256:0.09456805,Otu000169:0.013219067)0.894:0.043621712)1.000:0.092576062,(((Otu000633:0.030197631,(Otu000815:0.030101756,(((Otu000778:0.008149655,((Otu000369:0.037385051,((Otu000005:5e-09,Otu000276:0.021921759)0.754:0.002680294,Otu000447:0.023209515)0.783:0.006807602)0.388:0.005607871,(Otu000298:0.007599962,Otu000735:0.013080937)0.795:0.007890785)0.720:0.003393853)0.868:0.01330828,Otu000547:0.008678243)0.957:0.021831674,((Otu000013:0.001589924,(Otu000649:0.010345236,Otu000518:0.025471703)0.748:0.003346593)0.892:0.008205917,(Otu000151:0.005417402,Otu000394:0.023576438)0.764:0.004650448)0.847:0.010387491)0.936:0.019648615)0.909:0.013306372)0.845:0.008366876,((Otu000261:0.004546085,(Otu000384:0.020871594,((((((Otu000716:0.026610961,Otu000534:0.005878049)0.906:0.009253045,Otu000056:0.002747518)0.870:0.005098029,Otu000593:0.02350808)0.731:0.002117214,Otu000562:0.017811047)0.876:0.005044042,(Otu000025:6e-09,Otu000531:0.025993314)0.976:0.01275254)0.846:0.005519585,Otu000284:0.00717843)0.647:0.006490461)0.843:0.006511291)0.943:0.015901459,((Otu000464:0.049753345,((Otu000437:0.020472486,(Otu000182:0.032602626,Otu000203:0.033682626)0.989:0.04335894)0.842:0.015560048,((((Otu000010:5e-09,(((Otu000472:0.012697965,Otu000739:0.015331302)0.960:0.012777999,(Otu000711:0.015391416,(Otu000782:0.017197248,(Otu000497:0.018180122,Otu000506:0.012301953)0.492:0.004995439)0.760:0.003174837)0.851:0.00485704)0.768:0.002432916,Otu000602:0.020246986)0.822:5e-09)0.729:5e-09,(Otu000285:0.017838389,Otu000553:0.017806256)0.745:0.002836937)0.000:5e-09,((((Otu000157:0.010391038,(Otu000084:0.010359735,Otu000332:0.010024498)0.851:0.004869095)0.952:0.010301579,Otu000595:0.012943629)0.744:0.002233477,(Otu000038:5e-09,Otu000587:0.023262295)0.905:0.004965615)0.765:0.002509993,(Otu000664:0.021349541,Otu000679:0.01597816)0.682:0.001745958)0.980:0.012754823)0.852:0.013797838,Otu000232:0.010037636)0.906:0.014519066)0.851:0.012243931)0.489:0.007584164,(Otu000164:0.005155892,(Otu000068:0.012914499,Otu000051:0.015146879)0.429:0.002409624)0.959:0.016006815)0.791:0.007694606)0.970:0.017145383)0.360:0.00038572,(Otu000342:0.016908489,Otu000359:0.026373613)0.994:0.051142769)0.963:0.056655114)0.967:0.055978543,(((Otu000300:0.372158086,((Otu000064:5e-09,(Otu000249:0.033712799,((((Otu000436:0.021869054,(Otu000657:0.01149435,(Otu000219:0.009937705,Otu000306:0.015107466)0.878:0.011022428)0.196:0.003462802)0.432:0.005420507,Otu000461:0.019091189)0.723:0.002114615,Otu000006:6e-09)0.946:0.012114848,Otu000080:0.015503672)0.754:0.005205219)0.205:0.010525388)0.927:0.023941479,(Otu000542:0.000714789,((Otu000177:6e-09,(Otu000085:0.011612565,Otu000171:0.039549979)0.926:0.017671553)0.860:0.013585303,(Otu000070:0.014354443,((Otu000560:0.011481942,Otu000816:0.017535211)0.893:0.009703599,((Otu000493:0.015439441,(Otu000030:5e-09,(Otu000803:0.025121797,((Otu000197:0.003909314,Otu000569:0.017387721)0.919:0.010611295,(Otu000028:0.003940922,(Otu000287:0.01181184,Otu000260:0.013788908)0.550:0.004980948)0.748:0.004905279)0.353:0.008651279)0.909:0.019607399)0.610:0.007542997)0.000:5e-09,(((Otu000161:0.005132347,Otu000565:0.018088099)0.743:0.002433025,Otu000488:0.012873629)0.883:0.005187883,((((Otu000552:0.015449264,Otu000801:0.012532248)0.243:5e-09,Otu000702:0.009971772)0.873:0.004966616,((Otu000707:0.007459237,Otu000728:0.012565901)0.750:0.002456911,(Otu000636:0.012736691,Otu000189:0.010095524)0.768:0.002468054)0.753:0.002495351)0.820:0.007559999,Otu000029:5e-09)0.947:0.010168273)0.000:0.004970935)0.887:0.010599335)0.989:0.029536909)0.765:0 ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 19
#      16         intermediate_node_index += 1
#      18 # Isometric log-ratio transform
# ---> 19 X_ilr_with_tree = coda.transform_ilr(X + 1, tree)
#      20 # print(X_ilr_with_tree.iloc[:4,:4])
#      21 #                        y1        y2          y480            y3
#      22 # S-1409-45.B_RD1 -1.039407  1.655538 -2.464164e-17  6.189481e-16
#      23 # 1104.2_RD1      -0.673964  1.073470  4.192522e-18  3.923163e-16
#      24 # S-1409-42.B_RD1 -1.326432  2.112703  3.851113e-17  8.306736e-16
#      25 # 1073.1_RD1      -0.979605  1.560287  5.023995e-18  5.907717e-16
#
# File ~/.python/current/lib/python3.10/site-packages/compositional/compositional.py:95, in check_packages.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      93             print("Cannot import {}:".format(pkg_name), False, file=sys.stderr)
#      94 assert not missing_packages, "Please install the following packages to use this function:\n{}".format( ", ".join(missing_packages))
# ---> 95 return func(*args, **kwargs)
#
# File ~/.python/current/lib/python3.10/site-packages/compositional/compositional.py:1047, in transform_ilr(X, tree, check_polytomy, verbose)
#    1044     return _ilr_without_tree(X=X)
#    1045 # With tree
#    1046 else:
# -> 1047     return _ilr_with_tree(X=X, tree=tree)
#
# File ~/.python/current/lib/python3.10/site-packages/compositional/compositional.py:95, in check_packages.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      93             print("Cannot import {}:".format(pkg_name), False, file=sys.stderr)
#      94 assert not missing_packages, "Please install the following packages to use this function:\n{}".format( ", ".join(missing_packages))
# ---> 95 return func(*args, **kwargs)
#
# File ~/.python/current/lib/python3.10/site-packages/compositional/compositional.py:1036, in transform_ilr.<locals>._ilr_with_tree(X, tree)
#    1034 if tree_type == "ete":
#    1035     tree = _ete_to_skbio(tree=tree)
# -> 1036 return ilr_transform(table=X, tree=tree)
#
# File ~/.python/current/lib/python3.10/site-packages/gneiss/composition/_composition.py:43, in ilr_transform(table, tree)
#      41 _table, _tree = match_tips(table, tree)
#      42 basis, _ = balance_basis(_tree)
# ---> 43 balances = ilr(_table.values, basis)
#      44 in_nodes = [n.name for n in _tree.levelorder() if not n.is_tip()]
#      45 return pd.DataFrame(balances,
#      46                     columns=in_nodes,
#      47                     index=table.index)
#
# File ~/.python/current/lib/python3.10/site-packages/skbio/stats/composition.py:579, in ilr(mat, basis, check)
#     574         raise ValueError(
#     575             "Basis needs to be a 2D matrix, "
#     576             "not a %dD matrix." % (len(basis.shape))
#     577         )
#     578     if check:
# --> 579         _check_orthogonality(basis)
#     581 return clr(mat) @ basis.T
#
# File ~/.python/current/lib/python3.10/site-packages/skbio/stats/composition.py:1770, in _check_orthogonality(basis)
#    1768 basis = np.atleast_2d(basis)
#    1769 if not np.allclose(basis @ basis.T, np.identity(len(basis)), rtol=1e-4, atol=1e-6):
# -> 1770     raise ValueError("Basis is not orthonormal.")
#
# ValueError: Basis is not orthonormal.

# %%
fig, ax, prevalence_distribution = coda.plot_prevalence(X, classes=classes,  class_colors=class_colors, component_type="OTUs", show_prevalence=[1,2,0.5,1.0])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/matplotlib/style/core.py:137, in use(style)
#     136 try:
# --> 137     style = _rc_params_in_file(style)
#     138 except OSError as err:
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/__init__.py:866, in _rc_params_in_file(fname, transform, fail_on_error)
#     865 rc_temp = {}
# --> 866 with _open_file_or_url(fname) as fd:
#     867     try:
#
# File ~/.python/current/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/__init__.py:843, in _open_file_or_url(fname)
#     842 fname = os.path.expanduser(fname)
# --> 843 with open(fname, encoding='utf-8') as f:
#     844     yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'seaborn-white'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 fig, ax, prevalence_distribution = coda.plot_prevalence(X, classes=classes,  class_colors=class_colors, component_type="OTUs", show_prevalence=[1,2,0.5,1.0])
#
# File ~/.python/current/lib/python3.10/site-packages/compositional/compositional.py:95, in check_packages.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      93             print("Cannot import {}:".format(pkg_name), False, file=sys.stderr)
#      94 assert not missing_packages, "Please install the following packages to use this function:\n{}".format( ", ".join(missing_packages))
# ---> 95 return func(*args, **kwargs)
#
# File ~/.python/current/lib/python3.10/site-packages/compositional/compositional.py:1646, in plot_prevalence(X, minimum_count, component_type, color, classes, class_colors, marker_border_color, figsize, title, style, show_prevalence, show_xgrid, show_ygrid, show_legend, ylabel, xlabel, legend_kws, legend_title, title_kws, legend_title_kws, axis_label_kws, line_kws, fig_kws, scatter_kws, fill_kws, number_of_component_ticks, number_of_prevalence_ticks, fill, ax, checks)
#    1643                 tmp.append(x)
#    1644     return tmp
# -> 1646 with plt.style.context(style):
#    1648     if ax is  None:
#    1649         fig, ax = plt.subplots(**_fig_kws)
#
# File ~/.python/current/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/style/core.py:194, in context(style, after_reset)
#     192 if after_reset:
#     193     mpl.rcdefaults()
# --> 194 use(style)
#     195 yield
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/style/core.py:139, in use(style)
#     137         style = _rc_params_in_file(style)
#     138     except OSError as err:
# --> 139         raise OSError(
#     140             f"{style!r} is not a valid package style, path of style "
#     141             f"file, URL of style file, or library style name (library "
#     142             f"styles are listed in `style.available`)") from err
#     143 filtered = {}
#     144 for k in style:  # don't trigger RcParams.__getitem__('backend')
#
# OSError: 'seaborn-white' is not a valid package style, path of style file, URL of style file, or library style name (library styles are listed in `style.available`)
